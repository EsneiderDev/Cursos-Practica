# %% [markdown]
# pip install anthropic python-dotenv

# %%
# Make a starting list of messafes
message = []

#add in the initial user question of "Define quantum in one sentence"
add_user_message(message, "Define quantum computing in one sentence")

# Pass the list of messages into 'chat' to get an answer

# Take the answer and add it as an assistant message into our list

# Add in the users's follow-up question

# Call chat again with the list of messages to get a final answer
